# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from src.eda import EDA

# Load dataset and do EDA
eda = EDA('../data/raw/complaints.csv')
eda.product_distribution()
eda.narrative_length_analysis()
eda.missing_narratives()
# Out:
# d:\week-5\rag-complaint-chatbot\src\eda.py:9: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(file_path)
# Narrative Length Statistics:
# count    9.609797e+06
# mean     5.446667e+01
# std      1.497672e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      5.000000e+01
# max      6.469000e+03
# Name: narrative_length, dtype: float64
# Complaints with missing narratives: 6629041
# Complaints with narratives: 2980756
